# %%
import pandas as pd
import numpy as np
import csv
from scipy import stats
import os

matt = pd.read_csv("./9. Comparison/fdr_table.csv", header=None, na_values=["", "NaN"], keep_default_na=True, low_memory=False)
a_l = pd.read_csv("./9. Comparison/a_l.csv", header=None, na_values=["", "NaN"], keep_default_na=True, low_memory=False)

# Unique number of genes
gene_unique_matt = matt.iloc[:, 0].nunique()
gene_unique_a_l = a_l.iloc[:, 1].nunique()
print("Unique genes in M:", gene_unique_matt)
print("Unique genes in A+L:", gene_unique_a_l)
# Unique number of metabolites
met_unique_matt = matt.iloc[:, 1].nunique()
met_unique_a_l = a_l.iloc[:, 2].nunique()
print("Unique metabolites in M:", met_unique_matt)
print("Unique metabolites in A+L:", met_unique_a_l)


# Create real pairs as tuples
matt["pair"] = list(zip(matt.iloc[:, 0], matt.iloc[:, 1]))   # (gene, metabolite)
a_l["pair"]  = list(zip(a_l.iloc[:, 1], a_l.iloc[:, 2]))     # (gene, metabolite), skip first column
# Convert to sets
matt_pairs = set(matt["pair"])
a_l_pairs = set(a_l["pair"])
# True set-based comparisons
pairs_in_both = matt_pairs & a_l_pairs
pairs_only_matt = matt_pairs - a_l_pairs
pairs_only_a_l = a_l_pairs - matt_pairs

print(pairs_only_matt)

# Only Matt
df_matt_only = matt[matt["pair"].isin(pairs_only_matt)].iloc[:, 0:5]
# Only A_L
df_a_l_only = a_l[a_l["pair"].isin(pairs_only_a_l)].iloc[:, [1,2,12,13,17]]

"""
# Both
df_both_matt = matt[matt["pair"].isin(pairs_in_both)]
df_both_a_l  = a_l[a_l["pair"].isin(pairs_in_both)].iloc[:, 1:]
df_both = pd.concat([df_both_matt, df_both_a_l], axis=0)
"""

# Create output folder
os.makedirs("9. Comparison", exist_ok=True)  
df_matt_only.to_csv("./9. Comparison/unique_matt.csv", index=False, header=False)
df_a_l_only.to_csv("./9. Comparison/unique_a_l.csv", index=False, header=False)
#df_both.to_csv("common_pairs.csv", index=False, header=False)
# Out:
# Unique genes in M: 798
# Unique genes in A+L: 798
# Unique metabolites in M: 352
# Unique metabolites in A+L: 266
# {('ENSMUSG00000029878', '4-Cumylphenol'), ('ENSMUSG00000024873', 'Tris(trimethylsilyl)carbamate'), ('ENSMUSG00000039899', '1,2-Benzenedicarboxylic acid'), ('ENSMUSG00000026273', 'Acetin, bis-1,3-trimethylsilyl ether'), ('ENSMUSG00000034295', '(7a-Isopropenyl-4,5-dimethyloctahydroinden-4-yl)methanol'), ('ENSMUSG00000019699', 'Tacrine, N-trimethylsilyl-'), ('ENSMUSG00000019699', '2,4-Imidazolidinedione, 5,5-dimethyl-'), ('ENSMUSG00000051074', 'Palmitelaidic acid'), ('ENSMUSG00000026273', 'Cholesterol'), ('ENSMUSG00000024548', 'Fenitrothion'), ('ENSMUSG00000017802', 'Methyl-3-methoxy-5-methyl benzoate'), ('ENSMUSG00000026527', 'Ethanone, 1-(5-methoxy-2-methyl-3(1H)-indolyl)-'), ('ENSMUSG00000041720', 'Ser-Leu'), ('ENSMUSG00000024150', '5-Hydroxyhexanoic acid'), ('ENSMUSG00000046806', 'S-Methyl-L-cysteine'), ('ENSMUSG00000037012', '3-Methyladenine'), ('ENSMUSG00000022674', 'DL-Phenylalanine'), ('ENSMUSG00000034064', 'Allylescaline'), ('ENSMUSG00000022312', '3-Methyladenine'), ('ENSMUSG00000035011', '1-Octadecanol'), ('ENSMUSG00000032307', 'Pregn-16-en-20-one, 3,18-bis(acetyloxy)-14,15-epoxy-, (3beta,5alpha,14beta,15beta)-'), ('ENSMUSG00000026273', '2,4-Imidazolidinedione, 5,5-dimethyl-'), ('ENSMUSG00000018199', 'DL-Ornithine'), ('ENSMUSG00000042349', '1,3,5-Benzetriol'), ('ENSMUSG00000023341', '1,4-diazabicyclo[4.3.0]nonan-2,5-dione, 3-methyl '), ('ENSMUSG00000029684', 'Itaconic acid'), ('ENSMUSG00000059456', 'Sertraline carbamoyl glucuronide'), ('ENSMUSG00000031489', 'Ethanone, 1-(2,5-dimethoxyphenyl)-'), ('ENSMUSG00000056999', 'Glyoxime'), ('ENSMUSG00000045128', 'Pyrimidine, 5-methyl-2,4-bis[(trimethylsilyl)oxy]-'), ('ENSMUSG00000021990', '2,4-Imidazolidinedione, 5,5-dimethyl-'), ('ENSMUSG00000058756', 'Thiazolo[4,5-f]quinoline, 2,9-dimethyl-'), ('ENSMUSG00000020444', '2,4-Imidazolidinedione, 5,5-dimethyl-'), ('ENSMUSG00000034349', 'Octocrylene'), ('ENSMUSG00000058492', '2-Amino-4,6-dihydroxypyrimidine'), ('ENSMUSG00000037110', 'Benzenemethanamine, 2,3-dimethoxy-'), ('ENSMUSG00000067148', '5alpha-Pregnane-3,20-dione'), ('ENSMUSG00000007739', 'Cyclohexene, 3-butyl-3-methyl-1-trimethylsilyloxy-'), ('ENSMUSG00000007379', 'Citric acid'), ('ENSMUSG00000062421', '5-Hydroxyhexanoic acid'), ('ENSMUSG00000006476', '1,2,3,10,11,11a-Hexahydro-6,7,8-trimethoxy-3-oxo-5H-dibenzo(a,d)cycloheptene'), ('ENSMUSG00000053012', 'beta-D-Glucopyranose'), ('ENSMUSG00000015461', '5-Hydroxyhexanoic acid'), ('ENSMUSG00000038836', '(R*,S*)-2,3-Dihydroxybutanoic acid'), ('ENSMUSG00000011831', 'Butylmethylamine'), ('ENSMUSG00000031112', '2-Hydroxy-2-methylbutyric acid'), ('ENSMUSG00000021149', 'Alloxanic acid'), ('ENSMUSG00000025474', 'L-5-Oxoproline'), ('ENSMUSG00000052837', 'beta-D-Glucopyranose'), ('ENSMUSG00000023960', 'Acetin, bis-1,3-trimethylsilyl ether'), ('ENSMUSG00000040483', '5-Cholesten-3beta, 7alpha-bis[(trimethylsilyl)oxy]- '), ('ENSMUSG00000001687', 'Docosyl octyl ether'), ('ENSMUSG00000000127', 'D-Psicofuranose, pentakis'), ('ENSMUSG00000085207', '2-Aminoadipic acid'), ('ENSMUSG00000031479', 'Benzenemethanamine, 2,3-dimethoxy-'), ('ENSMUSG00000025104', 'Benzenemethanamine, 2,3-dimethoxy-'), ('ENSMUSG00000025474', 'Butylmethylamine'), ('ENSMUSG00000039804', 'Acetin, bis-1,3-trimethylsilyl ether'), ('ENSMUSG00000054484', '(pm)-N-Propylamphetamine'), ('ENSMUSG00000022199', 'Allylescaline'), ('ENSMUSG00000025060', 'alpha-Linolenic acid'), ('ENSMUSG00000017548', '1,3,5-Benzetriol'), ('ENSMUSG00000046947', '3-Hexenedinitrile'), ('ENSMUSG00000031147', 'Serine'), ('ENSMUSG00000021025', '15-Oxo-11Z,13E-eicosadienoic acid'), ('ENSMUSG00000040242', 'Cinnamic acid'), ('ENSMUSG00000096971', 'N-Methyl-N-(tetrahydro-2-furanylmethyl)-4-piperidinamine'), ('ENSMUSG00000064345', 'Ethanone, 1-(5-methoxy-2-methyl-3(1H)-indolyl)-'), ('ENSMUSG00000026820', 'D-(+)-Ribono-1,4-lactone (R,S,R)-'), ('ENSMUSG00000035941', 'Vanillylmandelic acid'), ('ENSMUSG00000029684', '1,4-Butanediol'), ('ENSMUSG00000097318', 'Glycine, N-[4-[(trimethylsilyl)oxy]benzoyl]-'), ('ENSMUSG00 ...
