# %%
import os
import pandas as pd
import numpy as np

def logarithm(file_name):
    # Read the CSV file
    df = pd.read_csv(file_name, header=None)

    # Select rows 3+, columns 2+
    numeric_part = df.iloc[2:, 1:]
    print(numeric_part)

    # Convert to numbers
    numeric_part = numeric_part.apply(pd.to_numeric, errors='coerce')

    # Apply log base 2 (x+1)
    numeric_part = np.log2(numeric_part + 1)

    # Put the transformed data back into the DataFrame
    df.iloc[2:, 1:] = numeric_part

    # Create output directory + output file path
    os.makedirs("3. Logarithm", exist_ok=True)
    base_name = os.path.basename(file_name)
    name, ext = os.path.splitext(base_name)
    new_file = os.path.join("3. Logarithm", f"{name}_log_x+1.csv")

    # Save
    df.to_csv(new_file, index=False, header=False)
    print(f"Saved {new_file}")

# ------------- Run -------------
logarithm("./2. Filter_CTRL/csf_DSS_CTRL_filtered.csv")
logarithm("./2. Filter_CTRL/csf_LPS_CTRL_filtered.csv")
logarithm("./2. Filter_CTRL/csf_VECPAC_CTRL_filtered.csv")
# Out:
#                1            2            3            4            5
# 2    61487.77617  44579.29945  51871.51156  56614.44142  106182.1573
# 3    252750.0188   677206.091  1708404.271  494893.0969  794283.0008
# 4              0            0            0            0            0
# 5     53866317.1    264784357  175183451.2  169333569.8    368473982
# 6    5909994.755  975.6771408  15581800.12  13227482.43  14653038.19
# ..           ...          ...          ...          ...          ...
# 334   1656812872   1911620482   2658717921   1258877469   2236315916
# 335  881.6654274  812.7423534  1078.203563  2112.415599   182.507155
# 336  20003605.42            0  18236018.36  13908637.36            0
# 337  4816584.377  3704625.999  2510222.018  2515779.225  3665496.747
# 338            0  67871.44629  81574.23062  72396.95611  71849.29316
#
# [337 rows x 5 columns]
# Saved 3. Logarithm/csf_DSS_CTRL_filtered_log_x+1.csv
#                1            2            3            4            5  \
# 2    47464.74921   45739.8119  67751.53899  88453.17167  51671.13438
# 3    282575.8162  309258.5477  461736.8571  286696.5322  681447.7673
# 4              0            0  568377.7956            0            0
# 5    159943413.7  254984932.1  207162826.3  87943612.81  12582882.56
# 6    23232741.84  37837710.62  23306348.67  177169.7685  1637.594377
# ..           ...          ...          ...          ...          ...
# 334   2016078474   1210171861  385419453.7   2747191615  324656639.3
# 335  862.4633549  409.4983567  421.2075335  419.4859625  5.444717259
# 336            0            0            0            0            0
# 337  2180270.028  3123284.554  4813920.613  4147045.748  2752113.136
# 338  64081.07806  70626.88505  99694.01355  140959.9138  41866.99585
#
#                6
# 2    69324.48248
# 3     1333647.17
# 4              0
# 5    183394553.3
# 6     21178771.4
# ..           ...
# 334   1125191175
# 335            0
# 336            0
# 337  2290776.449
# 338  60416.54098
#
# [337 rows x 6 columns]
# Saved 3. Logarithm/csf_LPS_CTRL_filtered_log_x+1.csv
#                1            2            3
# 2    60441.87655  34634.09876  124928.2394
# 3    1064662.302  419060.8465   706911.482
# 4              0            0  107810.3666
# 5     1240395978  214897209.6  68566428.78
# 6              0  90918.76324  8040.871983
# ..           ...          ...          ...
# 334  331348754.1   1431522677  135492452.7
# 335            0            0            0
# 336            0            0            0
# 337  1800606.364  1705540.547  1431129.931
# 338  48426.41647  28114.88288  38102.05218
#
# [337 rows x 3 columns]
# Saved 3. Logarithm/csf_VECPAC_CTRL_filtered_log_x+1.csv
