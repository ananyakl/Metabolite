# %%
import pandas as pd

# Load data
csf_nodes = pd.read_csv("../CSF-CPX/9. Effect Sign Prediction/CSF Effect Sign Predictions.csv") # columns: node, direction
ctx_nodes = pd.read_csv("./9. PUC/network_nodes.csv") # columns: ID, Mean Log2 Fold Change Direction (DSS)
edges = pd.read_csv("8. Filter FDR/final_edges_with_fdr_filtered.csv") # columns: Gene, Metabolite, Sign

# Build lookup maps
# Gene -> direction, from network_nodes
gene_direction_map = ctx_nodes.set_index("ID")["Mean Log2 Fold Change Direction (DSS)"].to_dict()

# Metabolite -> direction, from csf_nodes
metabolite_direction_map = csf_nodes.set_index("node")["direction"].to_dict()

# Map values onto edges
edges["ctx_direction"] = edges["Gene"].map(gene_direction_map)
edges["cpx_direction"] = edges["Metabolite"].map(metabolite_direction_map)

# Reorder so the new columns sit right next to their source columns
cols = list(edges.columns)
cols.remove("ctx_direction")
cols.remove("cpx_direction")

gene_idx = cols.index("Gene")
cols.insert(gene_idx + 1, "ctx_direction")

# recompute Metabolite's index since the list shifted after inserting ctx_direction
metabolite_idx = cols.index("Metabolite")
cols.insert(metabolite_idx + 1, "cpx_direction")

edges = edges[cols]

# Sanity check: report any genes/metabolites that didn't find a match
missing_genes = edges.loc[edges["ctx_direction"].isna(), "Gene"].unique()
missing_metabolites = edges.loc[edges["cpx_direction"].isna(), "Metabolite"].unique()
if len(missing_genes) > 0:
    print(f"Warning: {len(missing_genes)} gene(s) not found in network_nodes: {missing_genes}")
if len(missing_metabolites) > 0:
    print(f"Warning: {len(missing_metabolites)} metabolite(s) not found in csf_nodes: {missing_metabolites}")

# Step 5 ----------------------------------
edges["predicted_effect_sign"] = edges["ctx_direction"] * edges["cpx_direction"]

# Step 7 ----------------------------------
edges["within_model = pooled r"] = (
    edges["Pooled r"].fillna(edges["Sign"])
    .eq(edges["Sign"].map({"+": 1.0, "-": -1.0}))
) & edges["Consistent"]

edges["Sign"] = edges["Sign"].map({"+": 1.0, "-": -1.0})

# Step 8 ----------------------------------
edges["within-model = predicted"] = (
    edges["Sign"].eq(edges["predicted_effect_sign"])
) & edges["Consistent"].fillna(False)

# Step 9 ----------------------------------
edges["pooled = predicted"] = edges["Pooled r"].eq(edges["predicted_effect_sign"])

# Step 10 ----------------------------------
edges["all_signs_agree"] = (
    edges["within_model = pooled r"]
    == edges["within-model = predicted"]
) & (
    edges["within-model = predicted"]
    == edges["pooled = predicted"]
)

# Rename -----------------------------------
edges["Type_a"] = "CSF"
edges["Type_b"] = "RBN"

edges = edges.rename(columns={
    "Sign": "within_model_sign",
    "Metabolite": "CSF_name",
    "cpx_direction": "direction_CSF",
    "Type_a":"type_CSF",
    "Gene": "brain_name",
    "ctx_direction": "direction_brain",
    "Type_b":"type_brain",
})

# Select columns -----------------------------------
edges = edges[[
    "brain_name",
    "direction_brain",
    "type_brain",
    "CSF_name",
    "direction_CSF",
    "type_CSF",
    "VECPAC r",
    "LPS r",
    "DSS r",
    "Pooled r",
    "Consistent",
    "within_model_sign",
    "predicted_effect_sign",
    "within_model = pooled r",
    "within-model = predicted",
    "pooled = predicted",
    "all_signs_agree"
]]

# Save -----------------------------------
output_path = "9. PUC/final_edges_with_fdr_filtered_with_directions.csv"
edges.to_csv(output_path, index=False)
print(f"Saved: {output_path}")
print(edges.head())
# Out:
# Warning: 83 metabolite(s) not found in csf_nodes: ["3-Hydroxy-7,3',4',5'-tetramethoxyflavone" 'L-Val-L-Leu'
#  'N-[(3,4,5-Trimethoxyphenyl)methylidene]hydroxylamine' 'Tyr-Val'
#  '2-Aminoquinolin-8-ol' '2-Norbornanemethanol' 'Isosorbide'
#  'l-Leucine, n-butoxycarbonyl-N-methyl-, hexadecyl ester'
#  '1,2-Bis(trimethylsiloxy)cyclohexene' '13-Docosenamide, (Z)'
#  '3,4-Dihydroxybenzaldehyde'
#  '6-Aminocaproic acid, N-(tert.-butyldimethylsilyl)' 'L-(+)-Threose'
#  'Yangonin' '2,4-Dimethoxybenzaldoxime' '3-(4-Methoxyphenyl)coumarin'
#  'L-Ornithine' 'Octadecanoic acid'
#  '1,2-Cinnolinedicarboxylic acid, 1,2,3,5,6,7,8,8a-octahydro-4-trimethylsilyloxy-, diethyl ester'
#  '4,5-Dihydro-1H-pyrazole' 'Chlorobenzilate ' 'Glabridin'
#  '4-tert-Butyldimethylsiloxy-3-penten-2-one' 'Diclofenac'
#  '(9H-fluoren-9-yl)methanol, O-methoxycarbonyl-' 'cis-2-Decenoic acid'
#  '6-Nitroveratryl alcohol' 'Luciferin'
#  'tert-butyl(dimethyl)silyl-2-([tert-butyl(dimethyl)silyl]oxy)hex-2-enoate'
#  '3,3-Dimethylacrylic acid' '7-Hydroxy-4-(methoxymethyl)coumarin'
#  'Oxymorphone, bis(trimethylsilyl) ether' 'Benzene, 1-ethyl-3,5-dimethyl'
#  '1-Butanol' '1-Heptanol, 2-propyl-' '2-Butene-1,4-diol' 'Sulindac'
#  'L-Serine' 'Guanosine' 'Glycine'
#  'Glycine, tert.-butyldimethylsilyl ester' '4-Methylvaleric acid'
#  'Adipoyl-L-carnitine' '2-Allyl-1,4-dimethoxybenzene'
#  'Phenol, 2,4-bis(1-methyl-1-phenylethyl)-' '2-Methylcyclohexanol, (Z)'
#  'Octacosanol' '2-Butoxyethanol' '3-Methyl-3-buten-1-ol'
#  "2,4,4'-Trihydroxybenzophenone" 'Lupinine' 'Formamide'
#  'Iminodiacetic acid' '2-Buten-1-ol' 'Norephedrine' 'L-Pyroglutamic acid'
#  '3-Aminobenzoic acid' 'Prostaglandin' 'Benzeneacetic acid' 'Oleic Acid'
#  "2'-Hydroxy-2,4,4',5-tetramethoxychalcone" '3-Buten-2-one'
#  'Cytosine, N-(tert-butyldimethylsilyl)-'
#  'Dodecanoic acid, 1-methylethyl ester' 'L-Tryptophan'
#  '2,4-Di-tert-butylphenol' 'Butanedioic acid' 'Sarcosine'
#  '2-Methylcyclohexylamine, tert.-butyldimethylsilyl ether'
#  '1-Pentene, 1,3-diphenyl-1-(trimethylsilyloxy)-'
#  "6,7,4'-Trihydroxyisoflavone" 'Methyl lactate' 'Spiroxamine'
#  'Butyric Acid' 'Cyclobutylamine'
#  '9Z-Octadecenoic acid, (2S)-3-[(hydroxymercaptophosphinyl)oxy]-2-methoxypropyl ester '
#  "2',3'-Di-O-acetyladenosine" '2-Cyanobenzaldehyde' 'N-Acetyl-L-alanine'
#  '2,5-Dimethoxybenzonitrile' 'Lactic acid' 'Suberic acid'
#  'Isonicotinic Acid']
# Saved: 9. PUC/final_edges_with_fdr_filtered_with_directions.csv
#              brain_name  direction_brain type_brain  \
# 0  ENSMUSG00000000093-B             -1.0        RBN
# 1  ENSMUSG00000000093-B             -1.0        RBN
# 2  ENSMUSG00000000093-B             -1.0        RBN
# 3  ENSMUSG00000000093-B             -1.0        RBN
# 4  ENSMUSG00000000384-B              1.0        RBN
#
#                                             CSF_name  direction_CSF type_CSF  \
# 0           3-Hydroxy-7,3',4',5'-tetramethoxyflavone            NaN      CSF
# 1                                        L-Val-L-Leu            NaN      CSF
# 2  N-[(3,4,5-Trimethoxyphenyl)methylidene]hydroxy...            NaN      CSF
# 3                                            Tyr-Val            NaN      CSF
# 4                               2-Aminoquinolin-8-ol            NaN      CSF
#
#    VECPAC r  LPS r  DSS r  Pooled r  Consistent  within_model_sign  \
# 0       NaN    NaN    NaN      -1.0        True               -1.0
# 1       NaN    1.0    NaN       1.0        True                1.0
# 2       NaN    1.0    NaN       1.0        True                1.0
# 3       NaN    NaN    NaN      -1.0        True               -1.0
# 4       NaN    NaN    NaN       1.0        True                1.0
#
#    predicted_effect_sign  within_model = pooled r  within-model = predicted  \
# 0                    NaN                     True                     False
# 1                    NaN                     True                     False
# 2                    NaN                     True                     False
# 3                    NaN                     True                     False
# 4                    NaN                     True                     False
#
#    pooled = predicted  all_signs_agree
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False            False
