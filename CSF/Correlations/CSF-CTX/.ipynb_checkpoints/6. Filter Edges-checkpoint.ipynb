# %%
import numpy as np
import pandas as pd
import os


dss = pd.read_csv("./5. Metabolite Pairs/dss_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)
lps = pd.read_csv("./5. Metabolite Pairs/lps_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)
vecpac = pd.read_csv("./5. Metabolite Pairs/vecpac_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)
comb = pd.read_csv("./5. Metabolite Pairs/all_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)

# Remove first row from each (header)
dss = dss.iloc[1:].reset_index(drop=True)
lps = lps.iloc[1:].reset_index(drop=True)
vecpac = vecpac.iloc[1:].reset_index(drop=True)
comb = comb.iloc[1:].reset_index(drop=True)



# Get first two columns with transcriptomics and metabolomics names
first_two = dss.iloc[:, :2]

# Get third column (Spearmann Coefficients) for each file
vecpac_coef = vecpac.iloc[:, 2].reset_index(drop=True)
lps_coef    = lps.iloc[:, 2].reset_index(drop=True)
dss_coef    = dss.iloc[:, 2].reset_index(drop=True)
comb_coef   = comb.iloc[:, 2].reset_index(drop=True)

# ---------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------

same_sign = []
sign = []
temp = 0
for i in range(len(vecpac_coef)):
    
    v = pd.to_numeric(vecpac_coef.iloc[i], errors='coerce')
    l = pd.to_numeric(lps_coef.iloc[i],    errors='coerce')
    d = pd.to_numeric(dss_coef.iloc[i],    errors='coerce')
    p = pd.to_numeric(comb_coef.iloc[i],    errors='coerce')

    # try converting it to float and check if NaN
    try:
        vals = [float(v), float(l), float(d), float(p)]
    except:
        same_sign.append(False)
        sign.append("")
        continue 
# ---------------------------------------------------------------------------------------

    is_pos_consistent = (p > 0)
    
    is_neg_consistent = (p < 0)

# ---------------------------------------------------------------------------------------

    if (is_pos_consistent):
        same_sign.append(True)
        sign.append("+")
    elif (is_neg_consistent):
        same_sign.append(True)
        sign.append("-")
    else:
        same_sign.append(False)
        sign.append("")
        
    #print(temp, ": ", vals)
    temp = temp + 1

new_df = pd.DataFrame({
    "Gene": first_two.iloc[:, 0],
    "Metabolite": first_two.iloc[:, 1],
    "VECPAC r": vecpac_coef,

    "LPS r": lps_coef,
    "DSS r": dss_coef,
    "Pooled Data r": comb_coef,
    "Pooled P-value": comb.iloc[:, 3],
    "Consistent": same_sign,
    "Sign": sign
})


os.makedirs("6. Filter Edges", exist_ok=True)  
output_file_path = os.path.join("6. Filter Edges", "filtered_edges.csv") 
new_df.to_csv(output_file_path, index=False)
print("done")
# Out:
# /var/folders/0q/ndw_qsrd5cbch1pd347wrwx40000gn/T/ipykernel_72210/2338852206.py:6: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   dss = pd.read_csv("./5. Metabolite Pairs/dss_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)
# /var/folders/0q/ndw_qsrd5cbch1pd347wrwx40000gn/T/ipykernel_72210/2338852206.py:7: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   lps = pd.read_csv("./5. Metabolite Pairs/lps_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)
# /var/folders/0q/ndw_qsrd5cbch1pd347wrwx40000gn/T/ipykernel_72210/2338852206.py:8: DtypeWarning: Columns (2,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   vecpac = pd.read_csv("./5. Metabolite Pairs/vecpac_met_pair.csv", header=None, na_values=["", "NaN"], keep_default_na=True)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 39
#      37 l = pd.to_numeric(lps_coef.iloc[i],    errors='coerce')
#      38 d = pd.to_numeric(dss_coef.iloc[i],    errors='coerce')
# ---> 39 p = pd.to_numeric(comb_coef.iloc[i],    errors='coerce')
#      41 # try converting it to float and check if NaN
#      42 try:
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1753, in _iLocIndexer._getitem_axis(self, key, axis)
#    1750     raise TypeError("Cannot index by location index with a non-integer key")
#    1752 # validate the location
# -> 1753 self._validate_integer(key, axis)
#    1755 return self.obj._ixs(key, axis=axis)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1686, in _iLocIndexer._validate_integer(self, key, axis)
#    1684 len_axis = len(self.obj._get_axis(axis))
#    1685 if key >= len_axis or key < -len_axis:
# -> 1686     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
