# %%
import pandas as pd

# Read
dss = pd.read_csv("0. Original/CSF/dss_data.csv")
vecpac = pd.read_csv("0. Original/CSF/vecpac_data.csv")
lps = pd.read_csv("0. Original/CSF/lps_data.csv")
pooled = pd.read_csv("0. Original/CSF/pooled_data.csv")

# Save
dss.to_csv("3. Rename Metabolomics/dss.csv", index=False)
vecpac.to_csv("3. Rename Metabolomics/vecpac.csv", index=False)
lps.to_csv("3. Rename Metabolomics/lps.csv", index=False)
pooled.to_csv("3. Rename Metabolomics/pooled.csv", index=False)
