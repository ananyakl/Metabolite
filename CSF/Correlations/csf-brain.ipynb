# %%
import pandas as pd

ctx = pd.read_csv("CSF-CTX/9. PUC/final_edges_with_fdr_filtered_with_directions.csv")
rbn = pd.read_csv("CSF-RBN/9. PUC/final_edges_with_fdr_filtered_with_directions.csv")
stm = pd.read_csv("CSF-STM/9. PUC/final_edges_with_fdr_filtered_with_directions.csv")
cpx = pd.read_csv("CSF-CPX/11. Predict/final_edges_with_fdr_filtered_with_directions.csv")
csf = pd.read_csv("CSF-CSF/6. Prediction/prediction.csv")

# %%
combined = pd.concat([ctx, rbn, stm, cpx, csf], ignore_index=True)

print(combined.shape)
print(combined.head())

# Save
combined.to_csv("final_network.csv", index=False)
# Out:
# (680793, 29)
#              brain_name  direction_brain type_brain  \
# 0  ENSMUSG00000000326-C             -1.0        CTX
# 1  ENSMUSG00000000326-C             -1.0        CTX
# 2  ENSMUSG00000000326-C             -1.0        CTX
# 3  ENSMUSG00000000326-C             -1.0        CTX
# 4  ENSMUSG00000000326-C             -1.0        CTX
#
#                                             CSF_name  direction_CSF type_CSF  \
# 0                       (2,5-Dimethoxyphenyl)acetone            1.0      CSF
# 1  (2R)-Pyrrolidine-1,2-dicarboxylic acid, bis(te...           -1.0      CSF
# 2                     (4-Fluorophenyl)phenylmethanol            NaN      CSF
# 3      (9H-fluoren-9-yl)methanol, O-methoxycarbonyl-            NaN      CSF
# 4                        3,4,5-Trimethoxyamphetamine            1.0      CSF
#
#    VECPAC r  VECPAC n     LPS r  LPS n  ...  pooled_sign  \
# 0       NaN         2 -0.500000      3  ...          1.0
# 1       NaN         2 -0.500000      3  ...          1.0
# 2       NaN         1       NaN      1  ...          NaN
# 3       NaN         2 -0.866025      3  ...         -1.0
# 4       NaN         1 -1.000000      3  ...         -1.0
#
#    predicted_effect_sign  within_model = pooled  \
# 0                   -1.0                    NaN
# 1                    1.0                    NaN
# 2                    NaN                    NaN
# 3                    NaN                   -1.0
# 4                   -1.0                    NaN
#
#    number within_model = pooled_n  within_model = predicted  \
# 0                               1                       NaN
# 1                               1                       NaN
# 2                               0                       NaN
# 3                               2                       NaN
# 4                               1                       NaN
#
#    number within_model = predicted  predicted = pooled  \
# 0                                1                 NaN
# 1                                1                 1.0
# 2                                0                 NaN
# 3                                1                 NaN
# 4                                1                -1.0
#
#   number predicted = pooled  all_signs_agree  number all_signs_agree
# 0                         2              NaN                     NaN
# 1                         2              1.0                     2.0
# 2                         0              NaN                     NaN
# 3                         1             -1.0                     2.0
# 4                         2             -1.0                     2.0
#
# [5 rows x 29 columns]
