# %%
import pandas as pd

csf_cpx = pd.read_csv("../../8. Filter FDR/full_concord_fdr<0.15_final_edges_with_fdr_filtered.csv")
csf_cpx = csf_cpx[["Gene", "Metabolite", "Sign"]]
csf_cpx["Sign"] = csf_cpx["Sign"].replace({"+": 1,"-": -1})
csf_cpx["Gene"] = csf_cpx["Gene"].str.removesuffix("-P")
csf_cpx.to_csv("csf_cpx.csv", index=False)

csf_csf = pd.read_csv("../../../CSF-CSF/4. Filter FDR/final_edges_with_fdr_filtered.csv")
csf_csf = csf_csf[["Gene", "Metabolite", "Sign"]]
csf_csf["Sign"] = csf_csf["Sign"].replace({"+": 1,"-": -1})
csf_csf.to_csv("csf_csf.csv", index=False)

#cpx_nodes = pd.read_csv()
# Out:
# /var/folders/0q/ndw_qsrd5cbch1pd347wrwx40000gn/T/ipykernel_3955/2240993557.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   csf_cpx["Sign"] = csf_cpx["Sign"].replace({"+": 1,"-": -1})
# /var/folders/0q/ndw_qsrd5cbch1pd347wrwx40000gn/T/ipykernel_3955/2240993557.py:11: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   csf_csf["Sign"] = csf_csf["Sign"].replace({"+": 1,"-": -1})
