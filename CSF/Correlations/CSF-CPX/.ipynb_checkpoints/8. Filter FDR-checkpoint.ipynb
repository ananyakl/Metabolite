# %%
import pandas as pd
import numpy as np
from statsmodels.stats.multitest import fdrcorrection
import os

# Read file
df = pd.read_csv("./7. FDR Output/final_edges_with_fdr.csv")

# Keep only rows where Pooled FDR < 0.05
df_filtered = df[df["Pooled FDR"] < 0.05]

df_filtered.to_csv("./8. Filter FDR/final_edges_with_fdr_filtered.csv", index=False)
