# %%
import pandas as pd

ctx = pd.read_csv("CSF-CTX/9. PUC/final_edges_with_fdr_filtered_with_directions.csv")
rbn = pd.read_csv("CSF-RBN/9. PUC/final_edges_with_fdr_filtered_with_directions.csv")
stm = pd.read_csv("CSF-STM/9. PUC/final_edges_with_fdr_filtered_with_directions.csv")

# %%
combined = pd.concat([ctx, rbn, stm], ignore_index=True)

print(combined.shape)
print(combined.head())

# Save
combined.to_csv("combined_final_edges.csv", index=False)
# Out:
# (12536, 17)
#              brain_name  direction_brain type_brain                  CSF_name  \
# 0  ENSMUSG00000000326-C             -1.0        CTX     1-Heptanol, 2-propyl-
# 1  ENSMUSG00000000326-C             -1.0        CTX  3,3-Dimethylacrylic acid
# 2  ENSMUSG00000000326-C             -1.0        CTX   4,5-Dihydro-1H-pyrazole
# 3  ENSMUSG00000000326-C             -1.0        CTX                  Sulindac
# 4  ENSMUSG00000000827-C             -1.0        CTX  3,3-Dimethylacrylic acid
#
#    direction_CSF type_CSF  VECPAC r  LPS r  DSS r  Pooled r  Consistent  \
# 0            NaN      CSF       NaN   -1.0    NaN      -1.0        True
# 1            NaN      CSF       NaN    NaN    NaN      -1.0        True
# 2            NaN      CSF       NaN    NaN    NaN      -1.0        True
# 3            NaN      CSF       NaN    NaN    NaN       1.0        True
# 4            NaN      CSF       NaN    NaN    NaN       1.0        True
#
# ...
