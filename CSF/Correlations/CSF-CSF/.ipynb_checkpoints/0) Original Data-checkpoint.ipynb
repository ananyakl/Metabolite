# %%
import pandas as pd

# Read
dss = pd.read_csv("../../Quantile Normalization/6. Rename/csf_DSS_CTRL_normalized.csv")
vecpac = pd.read_csv("../../Quantile Normalization/6. Rename/csf_VECPAC_CTRL_normalized.csv")
lps = pd.read_csv("../../Quantile Normalization/6. Rename/csf_LPS_CTRL_normalized.csv")
pooled = pd.read_csv("../../Quantile Normalization/6. Rename/csf_pooled_CTRL_normalized.csv")

# Save
dss.to_csv("0. Original/dss_data.csv", index=False)
vecpac.to_csv("0. Original/vecpac_data.csv", index=False)
lps.to_csv("0. Original/lps_data.csv", index=False)
pooled.to_csv("0. Original/pooled_data.csv", index=False)
