# %%
import pandas as pd

dss = pd.read_csv("../Quantile Normalization/5. Normalized/csf_DSS_CTRL_normalized.csv")
lps = pd.read_csv("../Quantile Normalization/5. Normalized/csf_LPS_CTRL_normalized.csv").iloc[:, 1:]
vecpac = pd.read_csv("../Quantile Normalization/5. Normalized/csf_VECPAC_CTRL_normalized.csv").iloc[:, 1:]

pooled = pd.concat([dss, lps, vecpac], axis=1)
pooled.to_csv("../Quantile Normalization/5. Normalized/csf_pooled_CTRL_normalized.csv",index=False)
