# %%
import pandas as pd

# Read the CSV
df = pd.read_csv("./Feci/metabolomics_feci_dss.csv")

# Append '-P' to all values in the first column
first_col = df.columns[0]
df[first_col] = df[first_col].astype(str) + "-Feci"

# Save back to CSV (overwrite or use a new file name)
df.to_csv("./Feci/metabolomics_feci_dss_updated.csv", index=False)
